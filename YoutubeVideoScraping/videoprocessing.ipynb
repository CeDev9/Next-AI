# %%
from pytube import Search, YouTube
import json
import json
import os
import openai
outputfile = "youtube_data_yc_and_500_and_techstars.json"

# %% [markdown]
# First we download videos data from youtube using pytube

# %%
searchqueries = [("Y", "Y Combinator Application Videos", ["Y", ]),
                 ("Y", "Y Combinator Application Videos  2022", ["22", ]),
                 ("Y", "Y Combinator Application Videos  2021", ["21", ]),
                 ("Y", "Y Combinator Application Videos  2020", ["20", ]),
                 ("Y", "Y Combinator Application Videos  2019", ["19", ]),
                 ("Y", "Y Combinator Application Videos  2018", ["18", ]),
                 ("Y", "Y Combinator Application Videos  2017", ["17", ]),
                 ("Y", "Y Combinator Application Videos  2016", ["16", ]),
                 ("Y", "Y Combinator Application Videos  2015", ["15", ]),
                 # MassStartups:
                 ("Mass", "MassChallenge Application Videos", ["MASS", ]),
                 ("Mass", "MassChallenge Application Videos 2022", ["22", ]),
                 ("Mass", "MassChallenge Application Videos 2021", ["21", ]),
                 ("Mass", "MassChallenge Application Videos 2020", ["20", ]),
                 ("Mass", "MassChallenge Application Videos 2019", ["19", ]),
                 ("Mass", "MassChallenge Application Videos 2018", ["18", ]),
                 ("Mass", "MassChallenge Application Videos 2017", ["17", ]),
                 ("Mass", "MassChallenge Application Videos 2016", ["16", ]),
                 ("Mass", "MassChallenge Application Videos 2015", ["15", ]),
                 # 500 startups
                 ("500", "500 Startups Application Videos", ["500", ]),
                 ("500", "500 Startups Application Videos 2022", ["22", ]),
                 ("500", "500 Startups Application Videos 2021", ["21", ]),
                 ("500", "500 Startups Application Videos 2020", ["20", ]),
                 ("500", "500 Startups Application Videos 2019", ["19", ]),
                 ("500", "500 Startups Application Videos 2018", ["18", ]),
                 ("500", "500 Startups Application Videos 2017", ["17", ]),
                 ("500", "500 Startups Application Videos 2016", ["16", ]),
                 ("500", "500 Startups Application Videos 2015", ["15", ]),
                 # Techstars
                 ("Techstars", "Techstars Application Videos", ["TECH",]),
                 ("Techstars", "Techstars Pitch Videos", ["TECH",]),
                 ("Techstars", "Techstars Application Videos 2022", ["22", ]),
                 ("Techstars","Techstars Application Videos 2021", ["21", ]),
                 ("Techstars","Techstars Application Videos 2020", ["20", ]),
                 ("Techstars","Techstars Application Videos 2019", ["19", ]),
                 ("Techstars","Techstars Application Videos 2018", ["18", ]),
                 ("Techstars","Techstars Application Videos 2017", ["17", ]),
                 ("Techstars","Techstars Application Videos 2016", ["16", ]),
                 ("Techstars","Techstars Application Videos 2015", ["15", ]),
                 # AngelPad Application Videos
                 ("AngelPad","AngelPad Application Videos", ["ANGEL", ]),
                 ("AngelPad","AngelPad Application Videos 2022", ["22", ]),
                 ("AngelPad","AngelPad Application Videos 2021", ["21", ]),
                 ("AngelPad","AngelPad Application Videos 2020", ["20", ]),
                 ("AngelPad","AngelPad Application Videos 2019", ["19", ]),
                 ("AngelPad","AngelPad Application Videos 2018", ["18", ]),
                 ("AngelPad","AngelPad Application Videos 2017", ["17", ]),
                 ("AngelPad","AngelPad Application Videos 2016", ["16", ]),
                 ]

outdata = []
outtitles = []

def checkifallowed(word):
    upword = str(word.upper())
    if "APPL" in upword or "BATCH" in upword or "PITCH" in upword:
        return True
    return False
    

with open(outputfile, "w") as f:
    json.dump(outdata, f)
iind = 0
for accelerator, query, checkarr in searchqueries:
    searcher = Search(query)
    print(query, searcher.results)
    for i in range(0, 5):
        for yt in searcher.results:
            for check in checkarr:
                if (check in yt.title.upper()) and ( yt.title not in outtitles) and (checkifallowed(yt.title)):
                    print(yt.title)
                    print(str(yt))
                    print(str(yt.watch_url))
                    print(str(yt.publish_date))
                    outdata.append({
                        "id":iind,
                        "title": yt.title,
                        "url": yt.watch_url,
                        "author": yt.author,
                        "publish_date": str(yt.publish_date),
                        "description": yt.description,
                        "length": yt.length,
                        "views": yt.views,
                        "accelerator": accelerator,
                        "keywords": yt.keywords})
                    iind = iind + 1
                    outtitles.append(yt.title)
        searcher.get_next_results()
with open(outputfile, "w") as f:
    json.dump(outdata, f, indent=2)
# Out:
# Y Combinator Application Videos [<pytube.__main__.YouTube object: videoId=rpyvQJGcQGw>, <pytube.__main__.YouTube object: videoId=Rzlr2tNSl0U>, <pytube.__main__.YouTube object: videoId=ZA_WqDO47-E>, <pytube.__main__.YouTube object: videoId=4wbCVN1yLyA>, <pytube.__main__.YouTube object: videoId=TXYI1niJiyU>, <pytube.__main__.YouTube object: videoId=BBhAJwgTlZ4>, <pytube.__main__.YouTube object: videoId=8MdVFF5HU0g>, <pytube.__main__.YouTube object: videoId=42dSSiw30BU>, <pytube.__main__.YouTube object: videoId=TZoprxGzzMM>, <pytube.__main__.YouTube object: videoId=8kywFcXK6E4>, <pytube.__main__.YouTube object: videoId=F65Rt94K3C0>, <pytube.__main__.YouTube object: videoId=Zw7jS6_F-B4>, <pytube.__main__.YouTube object: videoId=cV-MwxhRTNI>, <pytube.__main__.YouTube object: videoId=Ve6cQTtY7aM>, <pytube.__main__.YouTube object: videoId=KrkjR8D9LcM>, <pytube.__main__.YouTube object: videoId=wdU1-dra7Zs>, <pytube.__main__.YouTube object: videoId=kZYaE8xg4cM>, <pytube.__main__.YouTube objec
# ...

# %% [markdown]
# Then we process the titles using GPT-3 to get the startup

# %%
import json
import os
import openai
openai.api_key = "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"
with open(outputfile, "r") as f:
    obj = json.load(f)

    with open("youtubetitles.txt", "w") as f2:
        print(len(obj))
        for yt in obj:
            strtowrite = yt["title"] + ":"
            print(yt["title"])
            response = openai.Completion.create(
                model="text-davinci-003",
                prompt="Name the startup from the following video title, give just the name:\n" +
                yt["title"],
                temperature=0.7,
                max_tokens=256,
                top_p=1,
                frequency_penalty=0,
                presence_penalty=0
            )
            print(response.choices[0].text.strip(" \n"))
            startupname = response.choices[0].text.strip(" \n")
            strtowrite = strtowrite + \
                response.choices[0].text.strip(" \n") + "\n"
            yt["startup"] = startupname
            f2.write(strtowrite)
        with open("youtubedata2.json", "w") as f:
            json.dump(obj, f, indent=2)
# Out:
# 625
# Weave's Application Video for YC W14
# Weave
# DoorDash's Application Video for YC S13
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\lukas\Desktop\NexUnicorn\videos\videoprocessing.ipynb Cell 5 in <cell line: 5>()
#      <a href='vscode-notebook-cell:/c%3A/Users/lukas/Desktop/NexUnicorn/videos/videoprocessing.ipynb#W4sZmlsZQ%3D%3D?line=10'>11</a> strtowrite = yt["title"] + ":"
#      <a href='vscode-notebook-cell:/c%3A/Users/lukas/Desktop/NexUnicorn/videos/videoprocessing.ipynb#W4sZmlsZQ%3D%3D?line=11'>12</a> print(yt["title"])
# ---> <a href='vscode-notebook-cell:/c%3A/Users/lukas/Desktop/NexUnicorn/videos/videoprocessing.ipynb#W4sZmlsZQ%3D%3D?line=12'>13</a> response = openai.Completion.create(
#      <a href='vscode-notebook-cell:/c%3A/Users/lukas/Desktop/NexUnicorn/videos/videoprocessing.ipynb#W4sZmlsZQ%3D%3D?line=13'>14</a>     model="text-davinci-003",
# ...

# %%
import os
from google.cloud import speech_v1p1beta1
from google.cloud.speech_v1p1beta1 import enums

# the directory containing the videos
video_dir = 'videos'

# create a client for the Speech-to-Text API
client = speech_v1p1beta1.SpeechClient()

# loop through the files in the directory
for file in os.listdir(video_dir):
    if file.endswith(".mp4") or file.endswith(".avi") or file.endswith(".mkv"):
        # get the audio from the video file
        audio = get_audio_from_video(file)

        # set up the configuration for the request
        config = {
            "language_code": "en-US",
            "sample_rate_hertz": 44100,
            "encoding": enums.RecognitionConfig.AudioEncoding.LINEAR16,
        }

        # set up the audio content for the request
        audio_content = audio.to_string()

        # make the request to the Speech-to-Text API
        response = client.recognize(config, audio_content)

        # loop through the results and print the transcriptions
        for result in response.results:
            print(result.alternatives[0].transcript)

# %%
ytobj = {}
with open(outputfile, "r") as f:
    ytobj = json.load(f)
for yt in ytobj:
    print(yt['id'],yt['startup'], yt['title'] )

# %%
import json
import os
import openai
import re
import time
openai.api_key = "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"
buffer = []
accelsrejects = []


def process_buffer(buffer):
    print("len exceed")
    titles = []
    for yt in buffer:
        titles.append(yt['title'])
    prompt = "Name the startups from the following video titles, give just the names in a list seperated by commas(Techstars is not a startup):\n" +                    "\n".join(titles)
    #print(prompt)
    success = False
    retries = 1
    while not success:
        try:
            response = openai.Completion.create(
                model="text-davinci-003",
                prompt=prompt,
                temperature=0.7,
                max_tokens=1000,
                top_p=1,
                frequency_penalty=0,
                presence_penalty=0
            )
            success = True
        except:
            time.sleep(retries*10)

    
    resp = response.choices[0].text.strip(" \n")
    print(response.choices[0].text.strip(" \n"))
    resparr = [st.strip() for st in re.split(r',|\n', resp) if st.strip() != '']
    print(resparr)
    resparr = filter_checkwords(resparr)
    print(resparr)
    for bufyt in buffer:
        bufyt['startup'] = ''
        for res in resparr:
            if any(re.search(r'\b{}\b'.format(x), res, re.IGNORECASE) for x in ["YC", "Y COMBINATOR", "Y-COMBINATOR", "YCOMBINATOR"]):
                print("################# IS Y COMBINATOR", bufyt['id'],'-', bufyt['title'],'-', res)
                accelsrejects.append((bufyt['id'], bufyt['title'], res))
                continue

            if any(re.search(r'\b{}\b'.format(x), res, re.IGNORECASE) for x in ["MASSCHALLENGE","MASS CHALLENGE"]):
                print("################# IS MASS CHALLENGE", bufyt['id'],'-', bufyt['title'],'-', res)
                accelsrejects.append((bufyt['id'], bufyt['title'], res))
                continue
            if any(re.search(r'\b{}\b'.format(x), res, re.IGNORECASE) for x in ["500 STARTUPS",]):
                print("################# IS 500 STARTUPS", bufyt['id'],'-', bufyt['title'],'-', res)
                accelsrejects.append((bufyt['id'], bufyt['title'], res))
                continue
            if any(re.search(r'\b{}\b'.format(x), res, re.IGNORECASE) for x in ["TECHSTARS","TECH STARS"]):
                print("################# IS TECHSTARS",bufyt['id'],'-', bufyt['title'],'-', res)
                accelsrejects.append((bufyt['id'], bufyt['title'], res))
                continue
            if any(re.search(r'\b{}\b'.format(x), res, re.IGNORECASE) for x in ["ANGELPAD","ANGEL PAD"]):
                print("################# IS ANGELPAD", bufyt['id'],'-', bufyt['title'],'-', res)
                accelsrejects.append((bufyt['id'], bufyt['title'], res))
                continue
            restricted_words = ['VIDEO', 'GRAND PITCHING FINALE', 'APPLICATION', 'AIR FORCE ACCELERATOR', 'ADVICE FOR ENTREPRENEURS', 'VERTICALS LAUNCH EVENT', "AGORA + MICROSOFT"]
            if any([x.upper() in res.upper() for x in restricted_words]):
                print("################# IS RESTRICTED WORD", bufyt['id'],'-', bufyt['title'],'-', res)
                accelsrejects.append((bufyt['id'], bufyt['title'], res))
                continue
            

            if res.strip(' \n') in bufyt['title']:
                print(bufyt['title'],'-', res)
                bufyt['startup'] = res

def filter_checkwords(startups):
    newstartups = []
    for res in startups:
        if any(re.search(r'\b{}\b'.format(x), res, re.IGNORECASE) for x in ["YC", "Y COMBINATOR", "Y-COMBINATOR", "YCOMBINATOR"]):
            continue
        if any(re.search(r'\b{}\b'.format(x), res, re.IGNORECASE) for x in ["MASSCHALLENGE","MASS CHALLENGE"]):
            continue
        if any(re.search(r'\b{}\b'.format(x), res, re.IGNORECASE) for x in ["500 STARTUPS",]):
            continue
        if any(re.search(r'\b{}\b'.format(x), res, re.IGNORECASE) for x in ["TECHSTARS","TECH STARS"]):
            continue
        if any(re.search(r'\b{}\b'.format(x), res, re.IGNORECASE) for x in ["ANGELPAD","ANGEL PAD"]):
            continue
        restricted_words = ['VIDEO', 'GRAND PITCHING FINALE', 'APPLICATION', 'AIR FORCE ACCELERATOR', 'ADVICE FOR ENTREPRENEURS', 'VERTICALS LAUNCH EVENT', "AGORA + MICROSOFT"]
        if any([x.upper() in res.upper() for x in restricted_words]):
            continue
        newstartups.append(res)
    return newstartups

with open(outputfile, "r") as f:
    obj = json.load(f)

    with open("youtubetitles.txt", "w") as f2:
        print(len(obj))
        
        for yt in obj:
            buffer.append(yt)
            if len(buffer) > 40:
                process_buffer(buffer)
                        

                buffer = []
        process_buffer(buffer)
        with open("youtubedata2.json", "w") as f:
            json.dump(obj, f, indent=2)
print("\n".join(["- ".join([str(ac) for ac in accel]) for accel in accelsrejects]))
        #     strtowrite = yt["title"] + ":"
        #     print(yt["title"])
        #     response = openai.Completion.create(
        #         model="text-davinci-003",
        #         prompt="Name the startup from the following video title, give just the name:\n" +
        #         yt["title"],
        #         temperature=0.7,
        #         max_tokens=256,
        #         top_p=1,
        #         frequency_penalty=0,
        #         presence_penalty=0
        #     )
        #     print(response.choices[0].text.strip(" \n"))
        #     startupname = response.choices[0].text.strip(" \n")
        #     strtowrite = strtowrite + \
        #         response.choices[0].text.strip(" \n") + "\n"
        #     yt["startup"] = startupname
        #     f2.write(strtowrite)
# Out:
# 622
# len exceed
# Weave, DoorDash, Suggestr, Embark Trucks, Beulr, Cyder, Witty, Slip, PickEasy, Bulletin, Hugecity, Favolog, Bullet, 8mg Health, Flip, Hokart, Ziivee, MerchEasy, Lollipuff, Virtual Project Room, Saent, Nightly, QT, Umbria Sciences, ShowCal.IO, myCOVIcare, Akrab, SousX, BizBezzie
# ['Weave', 'DoorDash', 'Suggestr', 'Embark Trucks', 'Beulr', 'Cyder', 'Witty', 'Slip', 'PickEasy', 'Bulletin', 'Hugecity', 'Favolog', 'Bullet', '8mg Health', 'Flip', 'Hokart', 'Ziivee', 'MerchEasy', 'Lollipuff', 'Virtual Project Room', 'Saent', 'Nightly', 'QT', 'Umbria Sciences', 'ShowCal.IO', 'myCOVIcare', 'Akrab', 'SousX', 'BizBezzie']
# ['Weave', 'DoorDash', 'Suggestr', 'Embark Trucks', 'Beulr', 'Cyder', 'Witty', 'Slip', 'PickEasy', 'Bulletin', 'Hugecity', 'Favolog', 'Bullet', '8mg Health', 'Flip', 'Hokart', 'Ziivee', 'MerchEasy', 'Lollipuff', 'Virtual Project Room', 'Saent', 'Nightly', 'QT', 'Umbria Sciences', 'ShowCal.IO', 'myCOVIcare', 'Akrab', 'SousX', 'BizBezzie']
# ...

# %%
with open("youtubedata2.json", "r") as f:
    ytobj = json.load(f)
    print(len(ytobj))
    for yt in ytobj:
        try:
            if yt['startup'].strip() == '':
                print(yt['id'], '-', yt['title'], '-',yt['startup'])
        except KeyError:
            print("KEYERROR")
            print(yt)
    print("STARTUPS")
    numstart = 0
    for yt in ytobj:
        try:
            if yt['startup'].strip() != '':
                print(yt['id'], '-',yt['startup'])
                numstart = numstart + 1
        except KeyError:
            print("KEYERROR")
            print(yt)
    print(numstart)
# Out:
# 622
# 2 - Applying to Y Combinator? 3 tips from a former YC partner -
# 3 - How to hack the YC application [startups] -
# 7 - Y Combinator Application Video -
# 10 - Tips on Applying to YC: A Demo -
# 16 - Y-Combinator Application Video -
# 17 - How to Apply and Succeed at Y Combinator by Dalton Caldwell -
# 18 - Clustr - Y Combinator Application Video -
# 20 - Y Combinator - Application Video -
# 21 - flip's Y combinator application video -
# 24 - Y-combinator Winter Application Video -
# 25 - Y combinator Application video -
# 30 - Dactic - Y Combinator Application Video (S21) -
# 33 - Y combinator application video. Introduction to our pre-stage company Umbria sciences LLC -
# 34 - Y Combinator 1 Min Application Video -
# 36 - Writing An Effective Y Combinator Application -
# 45 - Y-combinator application video. -
# 46 - Y Combinator Fellowship Application Video -
# 50 - Y Combinator - 1 Minute Application Video -
# 51 - Y combinator application video -
# ...

# %%
import json
with open("youtubedata2.json", "r") as f:
    with open("youtubedatafiltered.json", "w") as f2:
        ytobj = json.load(f)
        newytobj = [yt for yt in ytobj if yt['startup'].strip() != '']
        print(len(newytobj))
        json.dump(newytobj,f2, indent=2)
# Out:
# 414

# %%
from pytube import YouTube
import json
with open("youtubedatafiltered.json", "r") as f:
    ytobj = json.load(f)
    ytobj1 = ytobj[0]
    yt = YouTube(ytobj1['url'])
    yt.streams.filter(progressive=True, file_extension='mp4').order_by('resolution').desc().first().download(output_path='videos/')

# %%
from deepgram import Deepgram
import json

# The API key we created in step 3
DEEPGRAM_API_KEY = '123b5b58cb3539355817324324fbb18e67eb93ca'

# Replace with your file path and audio mimetype
PATH_TO_FILE = 'SOME_FILE.wav'
MIMETYPE = 'audio/wav'

def main():
    # Initializes the Deepgram SDK
    dg_client = Deepgram(DEEPGRAM_API_KEY)
    
    with open(PATH_TO_FILE, 'rb') as audio:
        source = {'buffer': audio, 'mimetype': MIMETYPE}
        options = { "punctuate": True, "model": "general", "language": "en-US", "tier": "enhanced" }
    
        print('Requesting transcript...')
        print('Your file may take up to a couple minutes to process.')
        print('While you wait, did you know that Deepgram accepts over 40 audio file formats? Even MP4s.')
        print('To learn more about customizing your transcripts check out developers.deepgram.com')
    
        response = dg_client.transcription.sync_prerecorded(source, options)
        print(json.dumps(response, indent=4))

main()

# %%
from pliers.stimuli import VideoStim
from pliers.converters import VideoFrameIterator
from pliers.filters import FrameSamplingFilter
from pliers.extractors import GoogleVisionAPIFaceExtractor, merge_results
from dotenv import load_dotenv
import os
load_dotenv()
API_KEY = os.getenv('GOOGLE_SPEECH_KEY')
video = VideoStim('my_movie.mpg')

# Convert the VideoStim to a list of ImageStims
conv = VideoFrameIterator()
frames = conv.transform(video)

# Sample 2 frames per second
filt = FrameSamplingFilter(hertz=2)
selected_frames = filt.transform(frames)

# Detect faces in all frames
ext = GoogleVisionAPIFaceExtractor()
face_features = ext.transform(selected_frames)

# Merge results from all frames into one big pandas DataFrame
data = merge_results(face_features)

# %%
from pliers.tests.utils import get_test_data_path
from os.path import join
from pliers.filters import FrameSamplingFilter
from pliers.converters import GoogleSpeechAPIConverter
from pliers.extractors import (ClarifaiAPIImageExtractor, GoogleVisionAPIFaceExtractor,
                               ComplexTextExtractor, PredefinedDictionaryExtractor,
                               STFTAudioExtractor, VADERSentimentExtractor,
                               merge_results)
from dotenv import load_dotenv
import os
load_dotenv()
video = join(get_test_data_path(), 'videos', 'Weaves_Application_Video_for_YC_W14.mp4')
# API_KEY = os.getenv('GOOGLE_SPEECH_KEY')
# Store all the returned features in a single list (nested lists
# are fine, the merge_results function will flatten everything)
features = []

# Sample video frames and apply the image-based extractors
sampler = FrameSamplingFilter(every=10)
frames = sampler.transform(video)

obj_ext = ClarifaiAPIImageExtractor()
obj_features = obj_ext.transform(frames)
features.append(obj_features)

face_ext = GoogleVisionAPIFaceExtractor()
face_features = face_ext.transform(frames)
features.append(face_features)

# Power in speech frequencies
stft_ext = STFTAudioExtractor(freq_bins=[(100, 300)])
speech_features = stft_ext.transform(video)
features.append(speech_features)

# Explicitly transcribe the video--we could also skip this step
# and it would be done implicitly, but this way we can specify
# that we want to use the Google Cloud Speech API rather than
# the package default (IBM Watson)
text_conv = GoogleSpeechAPIConverter()
text = text_conv.transform(video)

# Text-based features
text_ext = ComplexTextExtractor()
text_features = text_ext.transform(text)
features.append(text_features)

dict_ext = PredefinedDictionaryExtractor(
    variables=['affect/V.Mean.Sum', 'subtlexusfrequency/Lg10WF'])
norm_features = dict_ext.transform(text)
features.append(norm_features)

sent_ext = VADERSentimentExtractor()
sent_features = sent_ext.transform(text)
features.append(sent_features)

# Ask for data in 'long' format, and code extractor name as a separate
# column instead of prepending it to feature names.
df = merge_results(features, format='long', extractor_names='column')

# Output rows in a sensible order
df.sort_values(['extractor', 'feature', 'onset', 'duration', 'order']).head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\lukas\Desktop\NexUnicorn\videos\videoprocessing.ipynb Cell 13 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/lukas/Desktop/NexUnicorn/videos/videoprocessing.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> from os.path import join
#       <a href='vscode-notebook-cell:/c%3A/Users/lukas/Desktop/NexUnicorn/videos/videoprocessing.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a> from pliers.filters import FrameSamplingFilter
# ----> <a href='vscode-notebook-cell:/c%3A/Users/lukas/Desktop/NexUnicorn/videos/videoprocessing.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a> from pliers.converters import GoogleSpeechAPIConverter
# ...

# %%
import os

from pyAudioAnalysis import audioBasicIO
from pyAudioAnalysis import ShortTermFeatures
from pyAudioAnalysis import audioTrainTest as aT

# Set the directory where the videos are stored
video_dir = "videos"
audio_dir = "audio"

# Set the name of the trained model to use
model_name = "svm_rbf_speaker_male_female"


import os
from moviepy.editor import *

# Set the directory where the videos are stored
video_dir = "videos"

# Iterate over all videos in the directory
for video_file in os.listdir(video_dir):
    # Create a VideoFileClip object for the current video file
    video = VideoFileClip(os.path.join(video_dir, video_file))

    # Extract the audio from the video
    audio = video.audio

    # Save the audio to a file with the same name as the video file
    audio.write_audiofile(os.path.join(audio_dir, video_file.replace(".mp4", ".mp3")))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\lukas\Desktop\NexUnicorn\videos\videoprocessing.ipynb Cell 15 in <cell line: 22>()
#      <a href='vscode-notebook-cell:/c%3A/Users/lukas/Desktop/NexUnicorn/videos/videoprocessing.ipynb#X20sZmlsZQ%3D%3D?line=20'>21</a> # Iterate over all videos in the directory
#      <a href='vscode-notebook-cell:/c%3A/Users/lukas/Desktop/NexUnicorn/videos/videoprocessing.ipynb#X20sZmlsZQ%3D%3D?line=21'>22</a> for video_file in os.listdir(video_dir):
#      <a href='vscode-notebook-cell:/c%3A/Users/lukas/Desktop/NexUnicorn/videos/videoprocessing.ipynb#X20sZmlsZQ%3D%3D?line=22'>23</a>     # Create a VideoFileClip object for the current video file
# ...

# %%
# Iterate over all videos in the directory
for video_file in os.listdir(video_dir):
    # Read the audio data from the video file
    audiopath = os.path.join(video_dir, video_file.replace(".mp4", ".mp3"))
    print(audiopath)
    [Fs, x] = audioBasicIO.read_audio_file(audiopath)

    # Extract audio features from the audio data
    F, f_names = ShortTermFeatures.feature_extraction(x, Fs, 0.050*Fs, 0.025*Fs)

    # Use the trained model to classify the features and obtain the sentiment
    result, _, _, _, _ = aT.file_classification(features, "svm", model_name)

    # Print the sentiment of the video
    print(f"The sentiment of {video_file} is {result}")
# Out:
# videos\Weaves_Application_Video_for_YC_W14.mp3
# Error: file not found or other I/O error. (DECODING FAILED)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\lukas\Desktop\NexUnicorn\videos\videoprocessing.ipynb Cell 16 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/lukas/Desktop/NexUnicorn/videos/videoprocessing.ipynb#X21sZmlsZQ%3D%3D?line=5'>6</a> [Fs, x] = audioBasicIO.read_audio_file(audiopath)
#       <a href='vscode-notebook-cell:/c%3A/Users/lukas/Desktop/NexUnicorn/videos/videoprocessing.ipynb#X21sZmlsZQ%3D%3D?line=7'>8</a> # Extract audio features from the audio data
# ----> <a href='vscode-notebook-cell:/c%3A/Users/lukas/Desktop/NexUnicorn/videos/videoprocessing.ipynb#X21sZmlsZQ%3D%3D?line=8'>9</a> features, _ = ShortTermFeatures.feature_extraction(x, Fs, 0.05, 0.025)
# ...
